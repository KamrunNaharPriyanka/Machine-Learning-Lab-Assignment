# %%
#python print() function

name="Priyanka"
age=24

print("Name:", name, "Age:", age)

num1=7
num2=14

print("Num1:", num1, "Num2:", num2)
print("Sum=", num1+num2)
# Out:
# Name: Priyanka Age: 24
# Num1: 7 Num2: 14
# Sum= 21
